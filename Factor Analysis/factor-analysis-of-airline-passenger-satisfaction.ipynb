# %% [markdown]
# # Business Problem:
#
# * Can we categorize the dimensions of passenger's satisfaction into smaller number of Factors?
#
# In order to do that, we'll perform Factor Analysis.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dftrain = pd.read_csv('train.csv')
dftest = pd.read_csv('test.csv')
df_ori = pd.concat([dftrain, dftest], sort=False) # concatenate the train and test for generalizability
df = df_ori.copy()
df = df.iloc[:,8:24]
df = df.dropna() # checking missing data
df
# Out:
#        Inflight wifi service  Departure/Arrival time convenient  \
# 0                          3                                  4
# 1                          3                                  2
# 2                          2                                  2
# 3                          2                                  5
# 4                          3                                  3
# ...                      ...                                ...
# 25971                      3                                  3
# 25972                      4                                  4
# 25973                      2                                  5
# 25974                      3                                  3
# 25975                      2                                  5
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                           3              1               5                3
# 1                           3              3               1                3
# 2                           2              2               5                5
# 3                           5              5               2                2
# 4                           3              3               4                5
# ...                       ...            ...             ...              ...
# 25971                       3              1               4                3
# 25972                       4              4               4                4
# 25973                       1              5               2                1
# 25974                       3              3               4                4
# 25975                       2              5               4                2
#
#        Seat comfort  Inflight entertainment  On-board service  \
# 0                 5                       5                 4
# 1                 1                       1                 1
# 2                 5                       5                 4
# 3                 2                       2                 2
# 4                 5                       3                 3
# ...             ...                     ...               ...
# 25971             4                       4                 3
# 25972             4                       4                 4
# 25973             2                       2                 4
# 25974             4                       4                 3
# 25975             2                       1                 1
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                     3                 4                4                 5
# 1                     5                 3                1                 4
# 2                     3                 4                4                 4
# 3                     5                 3                1                 4
# 4                     4                 4                3                 3
# ...                 ...               ...              ...               ...
# 25971                 2                 4                4                 5
# 25972                 5                 5                5                 5
# 25973                 3                 4                5                 4
# 25974                 2                 5                4                 5
# 25975                 2                 1                1                 1
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                5                          25                      18.0
# 1                1                           1                       6.0
# 2                5                           0                       0.0
# 3                2                          11                       9.0
# 4                3                           0                       0.0
# ...            ...                         ...                       ...
# 25971            4                           0                       0.0
# 25972            4                           0                       0.0
# 25973            2                           0                       0.0
# 25974            4                           0                       0.0
# 25975            1                           0                       0.0
#
# [129487 rows x 16 columns]

# %% [markdown]
# The above dataframe shows all the parameters that contribute to passengers' satisfaction.

# %% [markdown]
# # Importing Factor Analyzer
# Let's install the package for factor analysis called Factor Analyzer.

# %%
pip install factor_analyzer # installing Factor Analyzer
# Out:
# Collecting factor_analyzer
#   Downloading factor_analyzer-0.3.2.tar.gz (40 kB)
#      |████████████████████████████████| 40 kB 2.3 MB/s
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from factor_analyzer) (1.2.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from factor_analyzer) (1.5.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from factor_analyzer) (1.19.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from factor_analyzer) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas->factor_analyzer) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->factor_analyzer) (2020.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->factor_analyzer) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->factor_analyzer) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->factor_analyzer) (1.0.0)
# Building wheels for collected packages: factor-analyzer
# done
#   Created wheel for factor-analyzer: filename=factor_analyzer-0.3.2-py3-none-any.whl size=40380 sha256=33069bd81d654ab773f55172723ba1460a8941977e99bb4ff439bb77f26480bb
#   Stored in directory: /root/.cache/pip/wheels/8d/9e/4c/fd4cb92cecf157b13702cc0907e5c56ddc48e5388134dc9f1a
# Successfully built factor-analyzer
# Installing collected packages: factor-analyzer
# Successfully installed factor-analyzer-0.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from factor_analyzer import FactorAnalyzer # Then, we import the installed package into our notebook.

# %% [markdown]
# # Testing a few Assumptions
# 1. Bartlett's Test: to check whether observed variables intercorrelate at all using the observed correlation matrix
# 2. Kaiser-Meyer-Olkin Test: to measures the suitability of data for factor analysis
#
# [Source](https://www.datacamp.com/community/tutorials/introduction-factor-analysis)

# %%
# Barlett's

from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
calculate_bartlett_sphericity(df)
# Out:
# (1100454.3463635414, 0.0)

# %%
# KMO

from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all, kmo_model = calculate_kmo(df)
print(kmo_model)
# Out:
# 0.7347314786302451

# %% [markdown]
# Both Bartlett's Test and KMO indicates that the dataframe is good to go for factor analysis.

# %% [markdown]
# # Identify the Number of Factors

# %%
# instantiate the Factor Analyzer
fa = FactorAnalyzer() 

# Fit the dataframe using Factor Analyzer
fa.fit(df)

# Identify the eigenvalues
ev, v = fa.get_eigenvalues() #eigenvalues

# display the eigenvalues
ev
# Out:
# array([3.80389837, 2.3721328 , 2.16956004, 1.96182794, 1.06300589,
#        0.94961228, 0.69607891, 0.53723377, 0.51374997, 0.46784182,
#        0.36634408, 0.32884042, 0.29332142, 0.25443665, 0.18743275,
#        0.03468288])

# %% [markdown]
# The above array of eigen values show that we can create five factors.

# %%
# Then, we repeat the factor analyzer using five factors, fitting it, and print the factor loadings for each variables.
fa = FactorAnalyzer(5, rotation='varimax')
fa.fit(df)
print(fa.loadings_)
# Out:
# [[ 9.51222546e-02  1.34785546e-01 -9.00112235e-03  6.14101713e-01
#    4.65372148e-01]
#  [-9.57623180e-03  5.54625878e-02 -2.96640256e-04  5.89526400e-01
#   -6.49139954e-03]
#  [-3.22972077e-02  3.10800908e-02 -2.35280251e-03  7.72955085e-01
#    4.48606165e-01]
#  [ 1.25845037e-02 -4.67148475e-02  4.77284147e-03  6.82653008e-01
#   -1.11332163e-01]
#  [ 7.70829828e-01  4.10135188e-03 -1.80185151e-02  3.06650437e-02
#    3.46802833e-02]
#  [ 2.89549138e-01  1.22384915e-01 -9.53510997e-03  1.08246330e-01
#    7.54004531e-01]
#  [ 7.56387764e-01  7.95257133e-02 -1.38440024e-02 -2.64576490e-02
#    2.09396959e-01]
#  [ 7.67525558e-01  4.66055426e-01 -7.83337084e-03  4.09450708e-02
#    2.32560644e-02]
#  [ 8.52709959e-02  7.01341669e-01 -1.92813548e-02  1.03362675e-02
#    4.71336116e-02]
#  [ 5.78302900e-02  4.86147655e-01  2.34399007e-02  4.31284274e-02
#    9.26339940e-02]
#  [ 3.64249934e-02  7.64505665e-01  6.93860766e-03  4.62035699e-02
#   -3.50870358e-02]
#  [ 1.13416171e-01  2.87751429e-01 -1.30508044e-02 -2.70974644e-02
#    1.33294577e-01]
#  [ 3.57487775e-02  7.99371091e-01 -4.43771540e-02  4.63690084e-02
#   -5.80222108e-02]
#  [ 8.54194578e-01  8.49490651e-02  6.47275852e-04 -1.29069489e-03
#    9.78446891e-02]
#  [-1.56801122e-02 -1.42312234e-02  9.68663656e-01  9.12086021e-05
#   -6.18584286e-03]
#  [-1.73449766e-02 -1.94197466e-02  9.95885348e-01 -8.00342843e-04
#   -8.27731108e-03]]

# %% [markdown]
# The above output is not human-eye friendly, so we make the below dataframes.

# %%
lmatrix = pd.DataFrame(fa.loadings_, index = list(df.columns), columns = ['Factor 1', 'Factor 2', 'Factor 3', 'Factor 4', 'Factor 5'])
lmatrix #loading matrix
# Out:
#                                    Factor 1  Factor 2  Factor 3  Factor 4  \
# Inflight wifi service              0.095122  0.134786 -0.009001  0.614102
# Departure/Arrival time convenient -0.009576  0.055463 -0.000297  0.589526
# Ease of Online booking            -0.032297  0.031080 -0.002353  0.772955
# Gate location                      0.012585 -0.046715  0.004773  0.682653
# Food and drink                     0.770830  0.004101 -0.018019  0.030665
# Online boarding                    0.289549  0.122385 -0.009535  0.108246
# Seat comfort                       0.756388  0.079526 -0.013844 -0.026458
# Inflight entertainment             0.767526  0.466055 -0.007833  0.040945
# On-board service                   0.085271  0.701342 -0.019281  0.010336
# Leg room service                   0.057830  0.486148  0.023440  0.043128
# Baggage handling                   0.036425  0.764506  0.006939  0.046204
# Checkin service                    0.113416  0.287751 -0.013051 -0.027097
# Inflight service                   0.035749  0.799371 -0.044377  0.046369
# Cleanliness                        0.854195  0.084949  0.000647 -0.001291
# Departure Delay in Minutes        -0.015680 -0.014231  0.968664  0.000091
# Arrival Delay in Minutes          -0.017345 -0.019420  0.995885 -0.000800
#
#                                    Factor 5
# Inflight wifi service              0.465372
# Departure/Arrival time convenient -0.006491
# Ease of Online booking             0.448606
# Gate location                     -0.111332
# Food and drink                     0.034680
# Online boarding                    0.754005
# Seat comfort                       0.209397
# Inflight entertainment             0.023256
# On-board service                   0.047134
# Leg room service                   0.092634
# Baggage handling                  -0.035087
# Checkin service                    0.133295
# Inflight service                  -0.058022
# Cleanliness                        0.097845
# Departure Delay in Minutes        -0.006186
# Arrival Delay in Minutes          -0.008277

# %% [markdown]
# Let's sort the dataframe based on each factor using cut off value 0.2.

# %%
lmatrix.sort_values('Factor 1', ascending=False)
# Out:
#                                    Factor 1  Factor 2  Factor 3  Factor 4  \
# Cleanliness                        0.854195  0.084949  0.000647 -0.001291
# Food and drink                     0.770830  0.004101 -0.018019  0.030665
# Inflight entertainment             0.767526  0.466055 -0.007833  0.040945
# Seat comfort                       0.756388  0.079526 -0.013844 -0.026458
# Online boarding                    0.289549  0.122385 -0.009535  0.108246
# Checkin service                    0.113416  0.287751 -0.013051 -0.027097
# Inflight wifi service              0.095122  0.134786 -0.009001  0.614102
# On-board service                   0.085271  0.701342 -0.019281  0.010336
# Leg room service                   0.057830  0.486148  0.023440  0.043128
# Baggage handling                   0.036425  0.764506  0.006939  0.046204
# Inflight service                   0.035749  0.799371 -0.044377  0.046369
# Gate location                      0.012585 -0.046715  0.004773  0.682653
# Departure/Arrival time convenient -0.009576  0.055463 -0.000297  0.589526
# Departure Delay in Minutes        -0.015680 -0.014231  0.968664  0.000091
# Arrival Delay in Minutes          -0.017345 -0.019420  0.995885 -0.000800
# Ease of Online booking            -0.032297  0.031080 -0.002353  0.772955
#
#                                    Factor 5
# Cleanliness                        0.097845
# Food and drink                     0.034680
# Inflight entertainment             0.023256
# Seat comfort                       0.209397
# Online boarding                    0.754005
# Checkin service                    0.133295
# Inflight wifi service              0.465372
# On-board service                   0.047134
# Leg room service                   0.092634
# Baggage handling                  -0.035087
# Inflight service                  -0.058022
# Gate location                     -0.111332
# Departure/Arrival time convenient -0.006491
# Departure Delay in Minutes        -0.006186
# Arrival Delay in Minutes          -0.008277
# Ease of Online booking             0.448606

# %%
lmatrix.sort_values('Factor 2', ascending=False)
# Out:
#                                    Factor 1  Factor 2  Factor 3  Factor 4  \
# Inflight service                   0.035749  0.799371 -0.044377  0.046369
# Baggage handling                   0.036425  0.764506  0.006939  0.046204
# On-board service                   0.085271  0.701342 -0.019281  0.010336
# Leg room service                   0.057830  0.486148  0.023440  0.043128
# Inflight entertainment             0.767526  0.466055 -0.007833  0.040945
# Checkin service                    0.113416  0.287751 -0.013051 -0.027097
# Inflight wifi service              0.095122  0.134786 -0.009001  0.614102
# Online boarding                    0.289549  0.122385 -0.009535  0.108246
# Cleanliness                        0.854195  0.084949  0.000647 -0.001291
# Seat comfort                       0.756388  0.079526 -0.013844 -0.026458
# Departure/Arrival time convenient -0.009576  0.055463 -0.000297  0.589526
# Ease of Online booking            -0.032297  0.031080 -0.002353  0.772955
# Food and drink                     0.770830  0.004101 -0.018019  0.030665
# Departure Delay in Minutes        -0.015680 -0.014231  0.968664  0.000091
# Arrival Delay in Minutes          -0.017345 -0.019420  0.995885 -0.000800
# Gate location                      0.012585 -0.046715  0.004773  0.682653
#
#                                    Factor 5
# Inflight service                  -0.058022
# Baggage handling                  -0.035087
# On-board service                   0.047134
# Leg room service                   0.092634
# Inflight entertainment             0.023256
# Checkin service                    0.133295
# Inflight wifi service              0.465372
# Online boarding                    0.754005
# Cleanliness                        0.097845
# Seat comfort                       0.209397
# Departure/Arrival time convenient -0.006491
# Ease of Online booking             0.448606
# Food and drink                     0.034680
# Departure Delay in Minutes        -0.006186
# Arrival Delay in Minutes          -0.008277
# Gate location                     -0.111332

# %%
lmatrix.sort_values('Factor 3', ascending=False)
# Out:
#                                    Factor 1  Factor 2  Factor 3  Factor 4  \
# Arrival Delay in Minutes          -0.017345 -0.019420  0.995885 -0.000800
# Departure Delay in Minutes        -0.015680 -0.014231  0.968664  0.000091
# Leg room service                   0.057830  0.486148  0.023440  0.043128
# Baggage handling                   0.036425  0.764506  0.006939  0.046204
# Gate location                      0.012585 -0.046715  0.004773  0.682653
# Cleanliness                        0.854195  0.084949  0.000647 -0.001291
# Departure/Arrival time convenient -0.009576  0.055463 -0.000297  0.589526
# Ease of Online booking            -0.032297  0.031080 -0.002353  0.772955
# Inflight entertainment             0.767526  0.466055 -0.007833  0.040945
# Inflight wifi service              0.095122  0.134786 -0.009001  0.614102
# Online boarding                    0.289549  0.122385 -0.009535  0.108246
# Checkin service                    0.113416  0.287751 -0.013051 -0.027097
# Seat comfort                       0.756388  0.079526 -0.013844 -0.026458
# Food and drink                     0.770830  0.004101 -0.018019  0.030665
# On-board service                   0.085271  0.701342 -0.019281  0.010336
# Inflight service                   0.035749  0.799371 -0.044377  0.046369
#
#                                    Factor 5
# Arrival Delay in Minutes          -0.008277
# Departure Delay in Minutes        -0.006186
# Leg room service                   0.092634
# Baggage handling                  -0.035087
# Gate location                     -0.111332
# Cleanliness                        0.097845
# Departure/Arrival time convenient -0.006491
# Ease of Online booking             0.448606
# Inflight entertainment             0.023256
# Inflight wifi service              0.465372
# Online boarding                    0.754005
# Checkin service                    0.133295
# Seat comfort                       0.209397
# Food and drink                     0.034680
# On-board service                   0.047134
# Inflight service                  -0.058022

# %%
lmatrix.sort_values('Factor 4', ascending=False)
# Out:
#                                    Factor 1  Factor 2  Factor 3  Factor 4  \
# Ease of Online booking            -0.032297  0.031080 -0.002353  0.772955
# Gate location                      0.012585 -0.046715  0.004773  0.682653
# Inflight wifi service              0.095122  0.134786 -0.009001  0.614102
# Departure/Arrival time convenient -0.009576  0.055463 -0.000297  0.589526
# Online boarding                    0.289549  0.122385 -0.009535  0.108246
# Inflight service                   0.035749  0.799371 -0.044377  0.046369
# Baggage handling                   0.036425  0.764506  0.006939  0.046204
# Leg room service                   0.057830  0.486148  0.023440  0.043128
# Inflight entertainment             0.767526  0.466055 -0.007833  0.040945
# Food and drink                     0.770830  0.004101 -0.018019  0.030665
# On-board service                   0.085271  0.701342 -0.019281  0.010336
# Departure Delay in Minutes        -0.015680 -0.014231  0.968664  0.000091
# Arrival Delay in Minutes          -0.017345 -0.019420  0.995885 -0.000800
# Cleanliness                        0.854195  0.084949  0.000647 -0.001291
# Seat comfort                       0.756388  0.079526 -0.013844 -0.026458
# Checkin service                    0.113416  0.287751 -0.013051 -0.027097
#
#                                    Factor 5
# Ease of Online booking             0.448606
# Gate location                     -0.111332
# Inflight wifi service              0.465372
# Departure/Arrival time convenient -0.006491
# Online boarding                    0.754005
# Inflight service                  -0.058022
# Baggage handling                  -0.035087
# Leg room service                   0.092634
# Inflight entertainment             0.023256
# Food and drink                     0.034680
# On-board service                   0.047134
# Departure Delay in Minutes        -0.006186
# Arrival Delay in Minutes          -0.008277
# Cleanliness                        0.097845
# Seat comfort                       0.209397
# Checkin service                    0.133295

# %%
lmatrix.sort_values('Factor 5', ascending=False)
# Out:
#                                    Factor 1  Factor 2  Factor 3  Factor 4  \
# Online boarding                    0.289549  0.122385 -0.009535  0.108246
# Inflight wifi service              0.095122  0.134786 -0.009001  0.614102
# Ease of Online booking            -0.032297  0.031080 -0.002353  0.772955
# Seat comfort                       0.756388  0.079526 -0.013844 -0.026458
# Checkin service                    0.113416  0.287751 -0.013051 -0.027097
# Cleanliness                        0.854195  0.084949  0.000647 -0.001291
# Leg room service                   0.057830  0.486148  0.023440  0.043128
# On-board service                   0.085271  0.701342 -0.019281  0.010336
# Food and drink                     0.770830  0.004101 -0.018019  0.030665
# Inflight entertainment             0.767526  0.466055 -0.007833  0.040945
# Departure Delay in Minutes        -0.015680 -0.014231  0.968664  0.000091
# Departure/Arrival time convenient -0.009576  0.055463 -0.000297  0.589526
# Arrival Delay in Minutes          -0.017345 -0.019420  0.995885 -0.000800
# Baggage handling                   0.036425  0.764506  0.006939  0.046204
# Inflight service                   0.035749  0.799371 -0.044377  0.046369
# Gate location                      0.012585 -0.046715  0.004773  0.682653
#
#                                    Factor 5
# Online boarding                    0.754005
# Inflight wifi service              0.465372
# Ease of Online booking             0.448606
# Seat comfort                       0.209397
# Checkin service                    0.133295
# Cleanliness                        0.097845
# Leg room service                   0.092634
# On-board service                   0.047134
# Food and drink                     0.034680
# Inflight entertainment             0.023256
# Departure Delay in Minutes        -0.006186
# Departure/Arrival time convenient -0.006491
# Arrival Delay in Minutes          -0.008277
# Baggage handling                  -0.035087
# Inflight service                  -0.058022
# Gate location                     -0.111332

# %% [markdown]
# * Factor 1: Cleanliness, Food and Drink, Inflight Entertainment, Seat Comfort
# * Factor 2: Inflight Services, Baggage Handling, Onboard Services, Leg Room
# * Factor 3: Arrival and Departure Delay
# * Factor 4: Online Booking, Gate Location, Inflight wifi, Departure/Arrival Time Convenience
# * Factor 5: Online Boarding

# %% [markdown]
# Of course we can simulate the number of factors towards other numbers, but I will stop until this point and you can further explore other possibilities.
